# %% [markdown]
# # MiniProject 1
# ## Data exploration

# %%
import pandas as pd
from pathlib import Path

# %%
raw_data = Path('rawdata')
tables = {}
for i, file in enumerate(raw_data.iterdir()):
    # if i > 10:
    #     break
    name = file.name.split('.')[0]
    tables[f"{name}"] = pd.read_csv(f"rawdata/{file.name}", header = None, names=('ID', name))

# %%
# Feed alls CSV files to one dataframe - not possible
'''
raw_data = Path('rawdata')
df_final = None
for file in raw_data.iterdir():
    df = pd.read_csv(file)
    df.columns = ["ID", file.name.split('.')[0]]  # Rename second column to file name for distinction
    
    if df_final is None:
        df_final = df
    else:
        df_final = pd.merge(df_final, df, on="ID")
display(df_final)
'''
# Out:
# Empty DataFrame
# Columns: [ID, starboardRudder, portPitch, level2median, fuelDensity, latitude, speedKnots, longitudinalWaterSpeed, trackDegreeTrue, windSpeed, trueHeading, starboardPitch, portRudder, longitude, fuelVolumeFlowRate, level1median, trackDegreeMagnetic, inclinometer-raw, windAngle, speedKmh, fuelTemp]
# Index: []
#
# [0 rows x 21 columns]

# %%
for name, table in tables.items():
    print(name)
    display(table.head())
    print(table.shape)
    print()

print('Min N of records',min([t.shape[0] for t in tables.values()]))
# Out:
# starboardRudder
#                    ID  starboardRudder
# 0  634018095135582500            3.142
# 1  634018095145588030            3.200
# 2  634018095155594280            3.202
# 3  634018095165605510            3.076
# 4  634018095175611210            3.078
# (1726076, 2)
#
# portPitch
#                    ID  portPitch
# 0  634018095135582500      2.127
# 1  634018095145588030      2.156
# 2  634018095155594280      2.295
# 3  634018095165605510      2.446
# 4  634018095175611210      2.469
# (1726076, 2)
#
# level2median
#                    ID  level2median
# 0  634018095128184147     13.935757
# 1  634018095131517480     13.953643
# 2  634018095134850813     13.912760
# 3  634018095138184146     13.961308
# 4  634018095141517479     14.009856
# (3840794, 2)
#
# fuelDensity
#                    ID  fuelDensity
# 0  634019142119225390     0.947109
# 1  634019142129597610     0.947110
# 2  634019142139821660     0.947114
# 3  634019142150036040     0.947104
# ...

# %% [markdown]
# It seems that sensors made measurements with different frequency.

# %%
'''
df = pd.merge(tables["starboardRudder"],tables["portPitch"],how='outer',on='ID')


for name, table in tables.items():
    if name in ("starboardRudder","portPitch"):
        continue
    df=pd.merge(df,table,how='outer',on='ID')
'''
# Out:
# '\ndf = pd.merge(tables["starboardRudder"],tables["portPitch"],how=\'outer\',on=\'ID\')\n\n\nfor name, table in tables.items():\n    if name in ("starboardRudder","portPitch"):\n        continue\n    df=pd.merge(df,table,how=\'outer\',on=\'ID\')\n'

# %% [markdown]
# Merging does not fit in the memory, therefore I decided to limit the trainning dataset to lower thousends. Which still should be enough to train decent enough model.

# %%
display(df.shape)
display(df.info())
display(df.describe())
display(df.nunique())
display(df.dtypes)

df.head(20)

# %%
import dask.dataframe as dd

# Load all CSVs as a Dask DataFrame
df = dd.read_csv("path_to_your_folder/*.csv")

# Perform operations as needed
df_final = df.compute()

# %%
suitable_ids = tables["longitudinalWaterSpeed"].ID
df = pd.DataFrame(suitable_ids.tolist(), columns = ['ID',])

# %%
df
# Out:
#                         ID
# 0       634018095159676190
# 1       634018095189470370
# 2       634018095220320480
# 3       634018095251911580
# 4       634018095283323350
# ...                    ...
# 548287  634067079031581980
# 548288  634067079064472660
# 548289  634067079095683600
# 548290  634067079126086800
# 548291  634067079157578330
#
# [548292 rows x 1 columns]

# %%
df.merge(tables["latitude"].ID,how='inner',on='ID')

'''
for name, table in tables.items():
    df=pd.merge(df,table.ID,how='inner',on='ID')
'''
# Out:
# "\nfor name, table in tables.items():\n    df=pd.merge(df,table.ID,how='inner',on='ID')\n"

# %%
df.head()
# Out:
#                    ID
# 0  634018095159676190
# 1  634018095189470370
# 2  634018095220320480
# 3  634018095251911580
# 4  634018095283323350

# %%
first_IDs = [table.ID[0] for table in tables.values()]
print(len(first_IDs))
for i in first_IDs:
    print(i)
first_IDs = pd.DataFrame(first_IDs)
len(first_IDs[0].unique())
# Out:
# 20
# 634018095135582500
# 634018095135582500
# 634018095128184147
# 634019142119225390
# 634018095137704470
# 634018095130693130
# 634018095159676190
# 634018095139168740
# 634018095148473090
# 634018095140997220
# 634018095135582500
# 634018095135582500
# 634018095137704470
# 634019142119225390
# 634018095128184147
# 634018095139168740
# 634018095130928380
# 634018095148473090
# 634018095130693130
# 634019142119225390
# 10
